# %% [markdown]
# <a href="https://colab.research.google.com/github/OM4R0/AIBootcamp/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/diabetes.csv")
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 768            4      110             92              0        0  37.6
# 769           10      168             74              0        0  38.0
# 770           10      139             80              0        0  27.1
# 771            1      189             60             23      846  30.1
# 772            5      166             72             19      175  25.8
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
for col in data.columns:
  print(f"column : {col}")
  print (f"unique values : {data[col].nunique()}")
  print(data[col].value_counts())
  print("-------------")
# Out:
# column : Pregnancies
# unique values : 17
# Pregnancies
# 1     136
# 0     111
# 2     103
# 3      75
# 4      69
# 5      58
# 6      50
# 7      45
# 8      38
# 9      28
# 10     26
# 11     11
# 13     10
# 12      9
# 14      2
# 17      1
# 15      1
# Name: count, dtype: int64
# -------------
# column : Glucose
# unique values : 136
# Glucose
# 99     17
# 100    17
# 111    14
# 125    14
# 129    14
#        ..
# 56      1
# 169     1
# 149     1
# 65      1
# 190     1
# Name: count, Length: 136, dtype: int64
# -------------
# column : BloodPressure
# unique values : 47
# BloodPressure
# 70     57
# 74     53
# 72     45
# 68     45
# 78     45
# 64     43
# 80     41
# 76     39
# 60     38
# 0      35
# 62     34
# 66     30
# 82     30
# 88     25
# 84     23
# 90     22
# 86     21
# 58     21
# 50     13
# 56     12
# 54     11
# 52     11
# 92      9
# 75      8
# 65      7
# 85      6
# 94      6
# 48      5
# 44      4
# 96      4
# 110     3
# 106     3
# ...

# %%
for column in data.columns:
  plt.figure(figsize=(8,5))
  data.boxplot([column])
  plt.title(f"boxplot of {column}")
  plt.show()

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
glucose_median=data['Glucose'].median()
data['Glucose']=data['Glucose'].replace(0,glucose_median)

# %%
blood_median=data['BloodPressure'].median()
data['BloodPressure']=data['BloodPressure'].replace(0,blood_median)

# %%
inulin_median=data['Insulin'].median()
data['Insulin']=data['Insulin'].replace(0,inulin_median)

# %%
q1=data['Insulin'].quantile(0.25)
q3=data['Insulin'].quantile(0.75)
iqr=q3-q1
upper_bound=q3+(1.5*iqr)
data['Insulin']=np.where(data['Insulin']>upper_bound,upper_bound,data['Insulin'])
upper_bound
# Out:
# np.float64(276.5)

# %%
plt.figure(figsize=(8,5))
data.boxplot(['Insulin'])
plt.title("boxplot of Insulin")
plt.show()

# %%
matrix=data.corr()
plt.figure(figsize=(15,10))
sns.heatmap(matrix,annot=True,cmap="coolwarm")
plt.show()
